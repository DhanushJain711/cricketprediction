# %%
import pandas as pd
import math

# %%
df = pd.read_csv('./combinedv2.csv')
# Out:
# C:\Users\Dhanush Jain\miniconda3\envs\mlcricket\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Drop null rows
df.drop(['version', '2.2.0', '2.1.0'], inplace=True, axis=1)
df.dropna(how = 'all', inplace = True)
df = df.dropna(subset=['match_id'])

# %%
# Create columns for total runs made and total wickets fallen
df['bat_run_total'] = df.groupby(['match_id', 'batting_team'])['runs_off_bat'].cumsum()
df['extras_total'] = df.groupby(['match_id', 'batting_team'])['extras'].cumsum()
df['run_total'] = df['bat_run_total'] + df['extras_total']
df['wickets'] = df.groupby(['match_id', 'batting_team'])['wicket_type'].transform(lambda x: x.notnull().cumsum())

# %%
# Create columns for overs left and run rate
def calc_overs_left(ball):
    return ((6 - int(str(ball)[-1])) / 10) + (20 - math.ceil(ball))

def calc_run_rate(ball, run_total):
    balls_passed = (6 * math.floor(ball)) + int(str(ball)[-1])
    return (run_total / balls_passed) * 6
    
df['overs_left'] = df['ball'].apply(calc_overs_left)
df['run_rate'] = df.apply(lambda row: calc_run_rate(row['ball'], row['run_total']), axis=1)

# %%
# Calculate striker and non-striker scores and strike rates
def calculate_scores(group):
    striker_score = 0
    non_striker_score = 0
    striker_rate = 0
    non_striker_rate = 0
    striker_scores = []
    non_striker_scores = []
    striker_rates = []
    non_striker_rates = []
    striker_balls = 0
    non_striker_balls = 0
    
    for _, row in group.iterrows():
        if pd.notna(row['wicket_type']):
            if row['player_dismissed'] == row['striker']:
                striker_score = 0
                striker_balls = 0
            elif row['player_dismissed'] == row['non_striker']:
                non_striker_score = 0
                non_striker_balls = 0
        
        striker_score += row['runs_off_bat']
        striker_balls += 1
        striker_rate = (striker_score / striker_balls) * 100
        
        striker_scores.append(striker_score)
        striker_rates.append(striker_rate)
        non_striker_scores.append(non_striker_score)
        non_striker_rates.append(non_striker_rate)
        
        # Swap scores if strike rotates
        if row['bat_run_total'] % 2 == 1:
            striker_score, non_striker_score = non_striker_score, striker_score
            striker_rate, non_striker_rate = non_striker_rate, striker_rate
            striker_balls, non_striker_balls = non_striker_balls, striker_balls
    
    group['striker_score'] = striker_scores
    group['non_striker_score'] = non_striker_scores
    group['striker_rate'] = striker_rates
    group['non_striker_rate'] = non_striker_rates
    return group

df = df.groupby('match_id').apply(calculate_scores).reset_index(drop=True)
df.head(20)
# Out:
#      match_id season start_date                                   venue  \
# 0   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 1   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 2   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 3   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 4   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 5   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 6   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 7   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 8   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 9   1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 10  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 11  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 12  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 13  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 14  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 15  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 16  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 17  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 18  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
# 19  1310981.0   2022  5/24/2022  Southend Club Cricket Stadium, Karachi
#
#     innings  ball batting_team bowling_team         striker     non_striker  \
# 0       1.0   0.1    Sri Lanka     Pakistan     GWHM Perera    AC Jayangani
# 1       1.0   0.2    Sri Lanka     Pakistan     GWHM Perera    AC Jayangani
# 2       1.0   0.3    Sri Lanka     Pakistan     GWHM Perera    AC Jayangani
# 3       1.0   0.4    Sri Lanka     Pakistan     GWHM Perera    AC Jayangani
# 4       1.0   0.5    Sri Lanka     Pakistan        H Madavi    AC Jayangani
# 5       1.0   0.6    Sri Lanka     Pakistan        H Madavi    AC Jayangani
# 6       1.0   1.1    Sri Lanka     Pakistan    AC Jayangani        H Madavi
# 7       1.0   1.2    Sri Lanka     Pakistan    AC Jayangani        H Madavi
# 8       1.0   1.3    Sri Lanka     Pakistan        H Madavi    AC Jayangani
# 9       1.0   1.4    Sri Lanka     Pakistan    AC Jayangani        H Madavi
# 10      1.0   1.5    Sri Lanka     Pakistan        H Madavi    AC Jayangani
# 11      1.0   1.6    Sri Lanka     Pakistan        H Madavi    AC Jayangani
# 12      1.0   2.1    Sri Lanka     Pakistan        H Madavi    AC Jayangani
# 13      1.0   2.2    Sri Lanka     Pakistan        H Madavi    AC Jayangani
# 14      1.0   2.3    Sri Lanka     Pakistan    AC Jayangani        H Madavi
# 15      1.0   2.4    Sri Lanka     Pakistan    AC Jayangani        H Madavi
# 16      1.0   2.5    Sri Lanka     Pakistan    AC Jayangani        H Madavi
# 17      1.0   2.6    Sri Lanka     Pakistan  MAA Sanjeewani        H Madavi
# 18      1.0   3.1    Sri Lanka     Pakistan        H Madavi  MAA Sanjeewani
# 19      1.0   3.2    Sri Lanka     Pakistan        H Madavi  MAA Sanjeewani
#
#     ... bat_run_total  extras_total  run_total  wickets  overs_left  \
# 0   ...           0.0           0.0        0.0        0        19.5
# 1   ...           4.0           0.0        4.0        0        19.4
# 2   ...           4.0           0.0        4.0        0        19.3
# 3   ...           4.0           0.0        4.0        1        19.2
# 4   ...           4.0           0.0        4.0        1        19.1
# 5   ...           4.0           0.0        4.0        1        19.0
# 6   ...           4.0           0.0        4.0        1        18.5
# 7   ...           5.0           0.0        5.0        1        18.4
# 8   ...           6.0           0.0        6.0        1        18.3
# 9   ...           7.0           0.0        7.0        1        18.2
# 10  ...           7.0           0.0        7.0        1        18.1
# 11  ...           8.0           0.0        8.0        1        18.0
# 12  ...           8.0           0.0        8.0        1        17.5
# 13  ...           9.0           0.0        9.0        1        17.4
# 14  ...           9.0           0.0        9.0        1        17.3
# 15  ...          13.0           0.0       13.0        1        17.2
# 16  ...          13.0           0.0       13.0        2        17.1
# 17  ...          13.0           0.0       13.0        2        17.0
# 18  ...          13.0           0.0       13.0        2        16.5
# 19  ...          14.0           0.0       14.0        2        16.4
#
#      run_rate  striker_score  non_striker_score striker_rate non_striker_rate
# 0    0.000000            0.0                0.0     0.000000         0.000000
# 1   12.000000            4.0                0.0   200.000000         0.000000
# 2    8.000000            4.0                0.0   133.333333         0.000000
# 3    6.000000            0.0                0.0     0.000000         0.000000
# 4    4.800000            0.0                0.0     0.000000         0.000000
# 5    4.000000            0.0                0.0     0.000000         0.000000
# 6    3.428571            0.0                0.0     0.000000         0.000000
# 7    3.750000            1.0                0.0    20.000000         0.000000
# 8    4.000000            1.0                1.0   100.000000        20.000000
# 9    4.200000            2.0                1.0   100.000000        20.000000
# 10   3.818182            1.0                2.0    16.666667       100.000000
# 11   4.000000            3.0                1.0   100.000000        16.666667
# 12   3.692308            3.0                1.0    75.000000        16.666667
# 13   3.857143            4.0                1.0    80.000000        16.666667
# 14   3.600000            1.0                4.0    14.285714        80.000000
# 15   4.875000            8.0                1.0   133.333333        14.285714
# 16   4.588235            0.0                8.0     0.000000       133.333333
# 17   4.333333            8.0                0.0   114.285714         0.000000
# 18   4.105263            0.0                8.0     0.000000       114.285714
# 19   4.200000            9.0                0.0   112.500000         0.000000
#
# [20 rows x 32 columns]

# %%
#Calculate final score corresponding to each ball (target variable)
def final_score(group):
    finalScore = group['run_total'].iloc[-1]
    for _, row in group.iterrows():
        group['final_score'] = finalScore
    return group

df = df.groupby(['match_id','batting_team']).apply(final_score).reset_index(drop=True)

# %%
#Save the dataframe for use in model training
df.to_csv('processed_data.csv', index=False)
